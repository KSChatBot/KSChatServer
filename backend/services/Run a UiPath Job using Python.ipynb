# %% [markdown]
# # Run a UiPath Job using Python.
# Orchestrator API 및 Python을 사용하여 작업(Job)을 실행하는 방법을 4 단계로 설명합니다.
# Orchestrator의 응답은 JSON 형식이므로 Python의 JSON 패키지를 사용하여 구문을 분석했습니다.

# %%
import requests
import json
import pandas as pd
from io import StringIO

# %% [markdown]
# ## 1 단계 : 인증 토큰 받기.
# Orchestrator는 서버가 사용자를 식별하기 위해 발행하는 비밀 값에 불과한 임시 베어러 토큰(bearer tokens)을 발행합니다. 이들은 수명이 짧으므로 정기적으로 재생성해야합니다.(24시간 유효)
# 토큰을 생성하려면 오케 스트레이터가 사용자를 식별하고 인증 할 수 있도록 몇 가지 정보를 제공해야합니다.
# ```
# user_data = """{
#     	"tenancyName": "Your_Tenant_Name",
#     	"usernameOrEmailAddress": "Your_Email_ID@email.com",
#     	"password": "Your_Password"
#     }"""
# ```
# 위에 표시된 것은 Bearer 토큰을 생성하는 데 필요한 최소 정보입니다. 위의 정보를 사용하여 다음 방법으로 전달하십시오.

# %%
user_data = """{
    "tenancyName": "Default",
    "usernameOrEmailAddress": "admin",
    "password": "1q2w3e4r!"
}"""
#     "tenancyName": "Default",

Base_URL="https://koreascoring.iptime.org"
path="/api/Account/Authenticate"
URL=Base_URL + path

# %%
def getUserToken(URL, user_data):
    data = requests.post(URL, json=json.loads(user_data), verify=False)
    authentication_data = json.loads(data.text)
    token = "Bearer " + str(authentication_data["result"])
    return token

# %%
token = getUserToken(URL,user_data)
token
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjBERDBEODAzNDk3QTMwMkM1NUMwQjA0MzlBQjgzQzk4QkE4QjIwMDEiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJEZERZQTBsNk1DeFZ3TEJEbXJnOG1McUxJQUUifQ.....Eci3rIyQH1gsIVYFJeupyC9jyQcaSjVYllvRhYZxNmOvym9Efzfj1F3aguyqfRBPoJlTqs9yMgWUtpOrp4kQ_WhOwZCr8xJ_eqs5Zl-DVmaw3aYnfYpGSt7vApIehS0YlS0a0NSG9DAJU6hFacwriXQh-Jq2jHMaNvBxuFPeV9ry4fvR4VW3SeYxYQJiVzhLyf_7K7rWRpbaEc05tQuZ-Ln7BYnwqW-tBhGT8wwgt0ozXap936nDvahf4pUqNLRtkNxRW8CrAQ_-AgsWANCI0xUHTPibE_iMu2CE1uJ_NWbWkLQh7hACzda24IpxZKTi1g1qiJp65_GixCSx5Rcnbg'

# %% [markdown]
# ## Orchestrator에등록된 프로세스 확인하기.
# /odata/Releases를 이용하여 등록된 프로세스 목록을 가져온다.

# %%
def getReleases(token):
#     process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
#                                 headers={"Authorization": token}, verify=False)
    process_data = requests.get(f"https://koreascoring.iptime.org/odata/Releases",
                                headers={"Authorization": token}, verify=False)
    process_json = json.loads(process_data.text)
    return process_json

# %%
releases_data = getReleases(token)
# 판다스이용 테이블 자료로 변환 
table_data = pd.DataFrame(releases_data['value'])
table_data
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#                                     Key             ProcessKey ProcessVersion  \
# 0  da8537d3-7dd5-4926-974f-7eb79b3d39ea                쇼핑몰상품이름          1.0.1
# 1  033f2564-164c-4ce9-baa8-5b65a0d433b2  Orchestrator_API_Test          1.0.3
#
#    IsLatestVersion  IsProcessDeleted                      Description  \
# 0            False             False  쇼핑몰 페이지를 접속하지 않고 원하는 상품 이름 가져오기
# 1            False             False                    Blank Process
#
#                                    Name  EnvironmentId EnvironmentName  \
# 0                   쇼핑몰상품이름_DemoProject              2     DemoProject
# 1  Orchestrator_API_Test_BotWithCognigy              5  BotWithCognigy
#
#       InputArguments  ... RequiresUserInteraction  AutoUpdate  \
# 0               None  ...                    True       False
# 1  {"in_Arg1":"RPA"}  ...                    True       False
#
#                                  FeedId  JobPriority  \
# 0  6f7ac8e9-9d48-4111-811c-4a9247bd938e       Normal
# 1  6f7ac8e9-9d48-4111-811c-4a9247bd938e       Normal
#
#                CreationTime OrganizationUnitId  \
# 0  2020-10-20T05:44:17.527Z                  1
# 1  2021-04-28T02:31:17.613Z                  1
#
#   OrganizationUnitFullyQualifiedName  Id  \
# 0                            Default  19
# 1                            Default  33
#
#                                            Arguments  ProcessSettings
# 0                    {'Input': None, 'Output': None}             None
# 1  {'Input': '[{"name":"in_Arg1","type":"System.S...             None
#
# [2 rows x 22 columns]

# %%
table_data[['Key','ProcessKey','InputArguments']]
# Out:
#                                     Key             ProcessKey  \
# 0  da8537d3-7dd5-4926-974f-7eb79b3d39ea                쇼핑몰상품이름
# 1  033f2564-164c-4ce9-baa8-5b65a0d433b2  Orchestrator_API_Test
#
#       InputArguments
# 0               None
# 1  {"in_Arg1":"RPA"}

# %%
json_list = json.loads(json.dumps(list(table_data[['Key','ProcessKey','InputArguments']].T.to_dict().values())))

# %%
json_list
# Out:
# [{'Key': 'da8537d3-7dd5-4926-974f-7eb79b3d39ea',
#   'ProcessKey': '쇼핑몰상품이름',
#   'InputArguments': None},
#  {'Key': '033f2564-164c-4ce9-baa8-5b65a0d433b2',
#   'ProcessKey': 'Orchestrator_API_Test',
#   'InputArguments': '{"in_Arg1":"RPA"}'}]

# %%
json_list[1]['InputArguments']
# Out:
# '{"in_Arg1":"RPA"}'

# %% [markdown]
# ## Orchestrator에등록된 로봇 확인하기.
# /odata/Robots를 이용하여 등록된 로봇 목록을 가져온다.

# %%
def getRobots(token):
#     process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
#                                 headers={"Authorization": token}, verify=False)
    robots_data = requests.get(f"https://koreascoring.iptime.org/odata/Robots",
                                headers={"Authorization": token}, verify=False)
    robots_json = json.loads(robots_data.text)
    return robots_json

# %%
robots_data = getRobots(token)
# 판다스이용 테이블 자료로 변환 
robots_table_data = pd.DataFrame(robots_data['value'])
robots_table_data
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#   LicenseKey      MachineName  MachineId         Name  \
# 0       None  DESKTOP-2L90K0T          3       baebae
# 1       None      CHATBOT-DEV         10  CHATBOT-DEV
#
#                    Username ExternalName Description Version           Type  \
# 0     DESKTOP-2L90K0T\sjkin         None     bae pro    None  NonProduction
# 1  chatbot-dev\koreascoring         None        None    None  NonProduction
#
#   HostingType  ... Password CredentialStoreId UserId  Enabled  CredentialType  \
# 0    Standard  ...     None              None      9    False            None
# 1    Standard  ...     None              None     28     True            None
#
#   RobotEnvironments IsExternalLicensed  LimitConcurrentExecution  Id  \
# 0       DemoProject              False                     False   3
# 1    BotWithCognigy              False                     False  11
#
#    ExecutionSettings
# 0               None
# 1               None
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Orchestrator에 처리된 작업(프로세스 실행 결과, 로봇작업결과) 확인하기.
# /odata/Jobs를 이용하여 등록된 로봇 목록을 가져온다.

# %%
def getJobs(token):
#     process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
#                                 headers={"Authorization": token}, verify=False)
    jobs_data = requests.get(f"https://koreascoring.iptime.org/odata/Jobs",
                                headers={"Authorization": token}, verify=False)
    jobs_json = json.loads(jobs_data.text)
    return jobs_json

# %%
jobs_data = getJobs(token)
# 판다스이용 테이블 자료로 변환 
jobs_table_data = pd.DataFrame(jobs_data['value'])
jobs_table_data
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
#                                      Key                 StartTime  \
# 0   4256c127-4f68-4875-8005-400311afb291  2020-10-20T06:31:58.743Z
# 1   be4e69cd-1b7f-44be-91d0-5b09ab742978   2020-10-20T23:10:00.39Z
# 2   c3c97b5a-8b8e-45cd-8f4b-3b1a88b398bf  2020-10-21T23:10:01.253Z
# 3   36d93d16-acab-483e-923b-86a082920821  2020-10-22T23:10:01.483Z
# 4   2e3f9160-bc5b-439c-ad7d-0a62fc800672  2020-10-28T08:38:02.487Z
# 5   246e9805-2d8e-4d3b-87a4-4f8e7cff4932  2020-10-28T23:10:01.037Z
# 6   b5c456d0-8874-4375-9998-002af64ed01d   2020-10-29T23:10:01.55Z
# 7   80218cae-3b64-4f67-8224-cc6d94f07164   2020-10-30T23:10:01.51Z
# 8   053eb2f3-de48-4563-9bbd-35426f407639  2020-10-31T23:10:01.413Z
# 9   6f203273-db59-4958-82f6-1082cbb80505  2020-11-01T23:10:01.597Z
# 10  d10d69bf-d736-4ba3-abed-3f8e227d131a  2020-11-02T23:10:00.407Z
# 11  0e555829-f0c0-42cd-b0bd-dcbdf176a8ec                      None
# 12  bd2f9664-066c-4528-a608-2b09cb519995   2021-04-28T02:34:42.44Z
# 13  15bef29f-d4ea-4881-85ef-aa6acc95cd44  2021-04-28T02:36:34.657Z
# 14  575b5510-f61e-43f4-b335-7ee406352eaf  2021-04-28T02:37:49.547Z
# 15  85a3f4cb-4fcc-4f91-a852-c8d20773c9d2  2021-04-28T03:05:17.543Z
# 16  b2f82ce5-b98c-487b-9d6c-b22cd4ddd6f9  2021-04-28T03:07:19.197Z
# 17  eb449257-4688-47c8-aa74-2cd2672c8439    2021-04-28T04:19:17.8Z
# 18  cc5d5acc-5df4-466d-bff2-86f676d4baa1  2021-04-28T04:37:13.603Z
# 31     Manual  5872f80b-b0e5-43d1-81b2-7b330087c52a
# 32     Manual  7eec4572-6978-4e9e-9986-c0c5b356786e
# 33     Manual  66d48c7c-631b-4665-aaa9-3c557e71def0
#
#                                                  Info  \
# 0                                        작업이 완료되었습니다.
# 1                                        작업이 완료되었습니다.
# 2                                        작업이 완료되었습니다.
# 3                                        작업이 완료되었습니다.
# 4                                                None
# 5                                        작업이 완료되었습니다.
# 6                                        작업이 완료되었습니다.
# 7                                        작업이 완료되었습니다.
# 8                                        작업이 완료되었습니다.
# 9                                        작업이 완료되었습니다.
# 10                                       작업이 완료되었습니다.
# 11                                               None
# 12                                       작업이 완료되었습니다.
# 13                                       작업이 완료되었습니다.
# 14                                       작업이 완료되었습니다.
# 15  작업 Orchestrator_API_Test_BotWithCognigy이(가) 중지...
# 16  작업 Orchestrator_API_Test_BotWithCognigy이(가) 중지...
# 17                                       작업이 완료되었습니다.
# 18                                       작업이 완료되었습니다.
# 19                                       작업이 완료되었습니다.
# 20                                       작업이 완료되었습니다.
# 21                                       작업이 완료되었습니다.
# 22                                       작업이 완료되었습니다.
# 23                                       작업이 완료되었습니다.
# 24                                       작업이 완료되었습니다.
# 25                                       작업이 완료되었습니다.
# 26                                       작업이 완료되었습니다.
# 27                                       작업이 완료되었습니다.
# 28                                       작업이 완료되었습니다.
# 29                                       작업이 완료되었습니다.
# 30                                       작업이 완료되었습니다.
# 31                                       작업이 완료되었습니다.
# 32                                       작업이 완료되었습니다.
# 33                                       작업이 완료되었습니다.
#
#                 CreationTime  ...  ResumeVersion StopStrategy    RuntimeType  \
# 0   2020-10-20T06:31:58.197Z  ...           None         None  NonProduction
# 1   2020-10-20T23:10:00.183Z  ...           None         None  NonProduction
# 2   2020-10-21T23:10:00.707Z  ...           None         None  NonProduction
# 3   2020-10-22T23:10:00.793Z  ...           None         None  NonProduction
# 4    2020-10-23T23:10:00.83Z  ...           None         Kill           None
# 5   2020-10-28T23:10:00.457Z  ...           None         None  NonProduction
# 6   2020-10-29T23:10:00.817Z  ...           None         None  NonProduction
# 7    2020-10-30T23:10:00.85Z  ...           None         None  NonProduction
# 8   2020-10-31T23:10:00.773Z  ...           None         None  NonProduction
# 9   2020-11-01T23:10:00.767Z  ...           None         None  NonProduction
# 10  2020-11-02T23:10:00.153Z  ...           None         None  NonProduction
# 11  2020-11-03T23:10:00.527Z  ...           None         None           None
# 12  2021-04-28T02:34:42.137Z  ...           None         None  NonProduction
# 13   2021-04-28T02:36:34.51Z  ...           None         None  NonProduction
# 14  2021-04-28T02:37:49.437Z  ...           None         None  NonProduction
# 15   2021-04-28T03:05:17.43Z  ...           None         Kill  NonProduction
# 16   2021-04-28T03:07:19.09Z  ...           None         Kill  NonProduction
# 17    2021-04-28T04:19:17.8Z  ...           None         None  NonProduction
# 18  2021-04-28T04:37:13.603Z  ...           None         None  NonProduction
# 19  2021-04-28T04:38:47.747Z  ...           None         None  NonProduction
# 20  2021-04-28T05:04:53.603Z  ...           None         None  NonProduction
# 21   2021-04-28T05:06:32.16Z  ...           None         None  NonProduction
# 22  2021-04-28T05:06:56.713Z  ...           None         None  NonProduction
# 23    2021-04-28T05:07:28.7Z  ...           None         None  NonProduction
# 24  2021-04-28T05:08:33.543Z  ...           None         None  NonProduction
# 25   2021-04-28T05:09:48.27Z  ...           None         None  NonProduction
# 26  2021-04-28T06:24:56.463Z  ...           None         None  NonProduction
# 27  2021-04-29T06:38:49.633Z  ...           None         None  NonProduction
# 28   2021-04-29T06:40:42.54Z  ...           None         None  NonProduction
# 29   2021-04-29T06:46:52.44Z  ...           None         None  NonProduction
# 30   2021-04-29T06:47:39.09Z  ...           None         None  NonProduction
# 31  2021-04-29T06:49:19.287Z  ...           None         None  NonProduction
# 32  2021-04-29T06:52:52.167Z  ...           None         None  NonProduction
# 33  2021-04-29T07:03:43.353Z  ...           None         None  NonProduction
#
#    RequiresUserInteraction ReleaseVersionId EntryPointPath  \
# 0                     True             19.0           None
# 1                     True             19.0           None
# 2                     True             19.0           None
# 3                     True             19.0           None
# 4                     True              NaN           None
# 5                     True             19.0           None
# 6                     True             19.0           None
# 7                     True             19.0           None
# 8                     True             19.0           None
# 9                     True             19.0           None
# 10                    True             19.0           None
# 11                    True              NaN           None
# 12                    True             51.0           None
# 13                    True             51.0           None
# 14                    True             51.0           None
# 15                    True             51.0           None
# 16                    True             51.0           None
# 17                    True              NaN           None
# 18                    True              NaN           None
# 19                    True             52.0           None
# 20                    True             52.0           None
# 21                    True              NaN           None
# 22                    True              NaN           None
# 23                    True              NaN           None
# 24                    True             52.0           None
# 25                    True             52.0           None
# 26                    True              NaN           None
# 27                    True             52.0           None
# 28                    True             52.0           None
# 29                    True              NaN           None
# 30                    True             53.0           None
# 31                    True             53.0           None
# 32                    True             53.0           None
# 33                    True             53.0           None
#
#     OrganizationUnitId OrganizationUnitFullyQualifiedName Reference   Id
# 0                    1                            Default            183
# 1                    1                            Default            191
# 2                    1                            Default            192
# 3                    1                            Default            193
# 4                    1                            Default            194
# 5                    1                            Default            195
# 6                    1                            Default            196
# 7                    1                            Default            198
# 8                    1                            Default            199
# 9                    1                            Default            200
# 10                   1                            Default            201
# 11                   1                            Default            202
# 12                   1                            Default            560
# 13                   1                            Default            561
# 14                   1                            Default            562
# 15                   1                            Default            563
# 16                   1                            Default            564
# 17                   1                            Default            565
# 18                   1                            Default            566
# 19                   1                            Default            567
# 20                   1                            Default            568
# 21                   1                            Default            569
# 22                   1                            Default            570
# 23                   1                            Default            571
# 24                   1                            Default            572
# 25                   1                            Default            573
# 26                   1                            Default            574
# 27                   1                            Default            578
# 28                   1                            Default            579
# 29                   1                            Default            580
# 30                   1                            Default            581
# 31                   1                            Default            582
# 32                   1                            Default            583
# 33                   1                            Default            584
#
# [34 rows x 28 columns]

# %% [markdown]
# ## 2 단계 : Process  ID를 가져옵니다.
# Process ID (릴리스 키(Release Key)라고도 함)는 오케 스트레이터에서 프로세스를 식별하는 고유 한 방법입니다. 프로세스의 이름을 사용하여 ID를 식별하고 검색합니다. 여기서 1 단계에서 생성 된 토큰과 함께 프로세스 이름을 전달하면됩니다.

# %%
def getProcessID(process_name, token):
#     process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
#                                 headers={"Authorization": token}, verify=False)
    process_data = requests.get(f"https://koreascoring.iptime.org/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
                                headers={"Authorization": token}, verify=False)
    process_json = json.loads(process_data.text)
    # print(json.dumps(process_json, indent=2))
    process_ID = process_json["value"][0]["Key"]
    return process_ID
#     return process_json

# %%
# process_name="쇼핑몰상품이름"
process_name="Orchestrator_API_Test" # ProcessKey = "Orchestrator_API_Test"
getProcessID(process_name,token)
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '033f2564-164c-4ce9-baa8-5b65a0d433b2'

# %% [markdown]
# ## 3 단계 : Robot ID를받습니다.
# 이제 우리는 프로세스를 실행할 로봇을 식별해야합니다. 이를 위해 로봇의 이름을 사용합니다.

# %%
def getRobotID(robotName, token):
#     robot_name = requests.get(f"https://platform.uipath.com/odata/Robots?$filter=Name%20eq%20'{robotName}'",
#                               headers={"Authorization": token})
    robot_name = requests.get(f"https://koreascoring.iptime.org/odata/Robots?$filter=Name%20eq%20'{robotName}'",
                              headers={"Authorization": token}, verify=False)
    robot_json_obj = json.loads(robot_name.text)
    robot_ID = robot_json_obj["value"][0]["Id"]
    return robot_ID

# %%
robotName="CHATBOT-DEV"
getRobotID(robotName,token)
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 11

# %% [markdown]
# ## 4 단계 : 봇을 실행합니다.
# 이제 모든 정보를 수집 한 후 다음 코드 스 니펫을 사용하여 봇을 실행하기 만하면됩니다.

# %%
def runJob(process_ID, robot_ID, token):
    start_job_json = """{ "startInfo":
       { "ReleaseKey": \"""" + process_ID + """\",
         "Strategy": "Specific",
         "RobotIds": [ """ + str(robot_ID) + """ ],
         "Source": "Manual",
         "InputArguments": "{'in_Arg1':'안녕 챗봇 테스트'}"        
       } 
    }"""  # InputArguments should be left {} or not included if workflow does not accept any input
    start_job_data = requests.post("https://koreascoring.iptime.org/odata/Jobs/UiPath.Server.Configuration.OData.StartJobs",
                                   json=json.loads(start_job_json), headers={"Authorization": token}, verify=False)
    return start_job_data

# %%
process_ID='033f2564-164c-4ce9-baa8-5b65a0d433b2'
robot_ID='11'
runJob(process_ID, robot_ID, token)
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <Response [201]>

# %% [markdown]
# ## 5 단계 : 봇 실행 결과를 확인합니다.
#  ‘/odata/Jobs({0})’로 작업 결과를 가져와 봇을 실행후 수행 결과를 확인합니다.

# %%
def getJobResult(token):
#     process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
#                                 headers={"Authorization": token}, verify=False)
    jobresult_data = requests.get(f"https://koreascoring.iptime.org/odata/Jobs({0})",
                                headers={"Authorization": token}, verify=False)
    jobresult_json = json.loads(jobresult_data.text)
    return jobresult_json

# %%
getJobResult(token)
# Out:
# C:\Users\koreascoring\reactapp\backend\env\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'koreascoring.iptime.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'message': 'Job이(가) 없습니다.', 'errorCode': 1002, 'resourceIds': None}

# %% [markdown]
# #### 여기서 주목할 몇 가지 사항-
# ##### 전략(Strategy) :
# 이 프로세스(process)를 실행하는 방법을 정의합니다. 'Specific'은 특정 로봇(a specific robot)에서이 프로세스를 실행하고자 함을 의미합니다. 'Dynamic'은 환경(environment)에서 사용 가능한 모든 봇(the available bots)에서 프로세스를 실행하고자 함을 의미합니다.
#
# ##### InputArguments :
# 프로세스의 입력 인수를 정의합니다. 프로세스에 인수가 없으면 비워 둡니다.
#
# #### 코드 및 결론.
# 그래서 이것이 파이썬을 통해 Orchestrator API를 사용하여 봇을 실행하는 방법입니다.
# 전체 코드는 아래에 있습니다.

# %%
import requests
import json


def getUserToken(URL, user_data):
    data = requests.post(url, json=json.loads(user_data))
    authentication_data = json.loads(data.text)
    token = "Bearer " + str(authentication_data["result"])
    return token


def getProcessID(process_name, token):
    process_data = requests.get(f"https://platform.uipath.com/odata/Releases?$filter=ProcessKey+eq%20'{process_name}'",
                                headers={"Authorization": token})
    process_json = json.loads(process_data.text)
    # print(json.dumps(process_json, indent=2))
    process_ID = process_json["value"][0]["Key"]
    return process_ID


def getRobotID(robotName, token):
    robot_name = requests.get(f"https://platform.uipath.com/odata/Robots?$filter=Name%20eq%20'{robotName}'",
                              headers={"Authorization": token})
    robot_json_obj = json.loads(robot_name.text)
    robot_ID = robot_json_obj["value"][0]["Id"]
    return robot_ID


def runJob(process_ID, robot_ID, token):
    start_job_json = """{ "startInfo":
       { "ReleaseKey": \"""" + process_ID + """\",
         "Strategy": "Specific",
         "RobotIds": [ """ + str(robot_ID) + """ ],
         "Source": "Manual",
         "InputArguments": "{'in_Arg1':'Aloha'}"        
       } 
    }"""  # InputArguments should be left {} or not included if workflow does not accept any input
    start_job_data = requests.post("https://platform.uipath.com/odata/Jobs/UiPath.Server.Configuration.OData.StartJobs",
                                   json=json.loads(start_job_json), headers={"Authorization": token})
    return start_job_data



if __name__ == "__main__":
    # ---Steps to run a JOB---

    # ---Step 1. - Get the Orchestrator TOKEN---
    # Authentication Data
    
    tenant_name = str(input("Please enter the Tenant Name: \n"))
    owner_name = str(input("Please enter the Tenant Name: \n"))
    tenant_email  = str(input("Please enter the Tenant Email: \n"))
    tenant_password  = str(input("Please enter the Tenant Password: \n"))
    url = furl = r"https://platform.uipath.com/{owner_name}/{tenant_name}/api/Account/Authenticate"
    user_data = """{
        	"tenancyName": \"""" + tenant_name + """\",
        	"usernameOrEmailAddress": \"""" + tenant_email +"""\",
        	"password": \""""+ tenant_password + """\"
        }"""
    token = getUserToken(url, user_data)
    print("Token = " + token)

    # ---Step 2. - Get PROCSS_ID of process you want to run---
    process_name = str(input("Please enter the Process Name: \n"))
    process_ID = getProcessID(process_name, token)
    print(f"Process ID = {process_ID}")

    # ---Step 3. - Get the ROBOT_ID of robot you want to run process on---
    robot_name = str(input("Please enter the Robot Name: \n"))
    robot_ID = getRobotID(robot_name, token)
    print(f"Robot ID = {robot_ID}")

    # ---Step 4. - START_Job---
    start_job_data = runJob(process_ID, robot_ID, token)
    print("Job Status = " + str(start_job_data))
