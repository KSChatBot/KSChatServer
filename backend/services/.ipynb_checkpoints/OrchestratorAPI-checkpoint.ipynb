# %%
import requests, json
from bs4 import BeautifulSoup

# %%
def getAuthKey(url,tenancyName,userName,password):
    # api_url = "https://platform.uipath.com/jwpark/jwpark:443"
    data = {
        "tenancyName": tenancyName,
        "usernameOrEmailAddress": userName,
        "password": password

    }
    headers={'Content-type':'application/json', 'Accept':'application/json'}

    sess = requests.Session()
    req = requests.post(url+"/api/Account/Authenticate", json=data, headers=headers, verify=False)
    if(req.status_code == 200):
        resJson = req.json()
        return resJson["result"]
    else:
        return None

def postUiPathAPI(url,key,data):
    # api_url = "https://platform.uipath.com/jwpark/jwpark:443"
    head = {
        "Content-Type" : "application/json",
        "Authorization" : "Bearer " + key
    }
    
    req = requests.post(url,json.dumps(data),headers=head,verify=False)
    if(req.status_code == 200 or req.status_code == 201):
        return req.json()
    else:
        print(BeautifulSoup(req.text,'lxml'))
        return None

def getUiPathAPI(url,key):
    # api_url = "https://platform.uipath.com/jwpark/jwpark:443"
    head = {
        "Content-Type" : "application/json",
        "Authorization" : "Bearer " + key
    }
    
    req = requests.get(url,headers=head,verify=False)
    if(req.status_code == 200):
        return req.json()
    else:
        print(BeautifulSoup(req.text,'lxml'))
        return None

def pretty(reqJson):
#     print(reqJson)
    for k in reqJson:
        print(k + " : " + str(reqJson[k]))

# %%
url="https://koreascoring.iptime.org"
# tenancyName="Default"
tenancyName="HMC"
userName="admin"
password="1q2w3e4r!"
result = getAuthKey(url,tenancyName,userName,password)
print(result)
# Out:
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# eyJhbGciOiJSUzI1NiIsImtpZCI6IjBERDBEODAzNDk3QTMwMkM1NUMwQjA0MzlBQjgzQzk4QkE4QjIwMDEiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJEZERZQTBsNk1DeFZ3TEJEbXJnOG1McUxJQUUifQ.....JSGHfyYTPkIOejSwKoG1h9gjiHeWd1iqkDUylkyCZ_2KpetTsZgA7S2QqVgsV6n4OOUh0UxDJgg7EbVVn_gOpQm8mtl6qJhO7PC_cmIOVM1R4mGE7V63Lu1kaeqiDabcDHsiCtkNQ9hDPahS7MRwtXJ_NU-zRnmTSNXgHyvBcg0Vcj2i8jFVrnfe3jLC64PfvTFb6Ykw4PGEm3ET3nynaphNi5ICRb24LnIlafolo5Eh7N-GT_V_a6ChYMk3-7So-zZ5UTCROgj2OB14CYyKvnMhu1WrhPoxIaVWuBQxgqDdaaLxzhBal-Ry-NGviFL4TFORqS5zpy0CbSx9rDj_lA

# %%
## Robot Info, Job Info등
## Job 실행
my_endpoint = "https://koreascoring.iptime.org"
api_url = {
    'Robots':my_endpoint+"/odata/Robots",
    "Jobs":my_endpoint+"/odata/Jobs",
    "Processes":my_endpoint+"/odata/Processes",
    "Releases":my_endpoint+"/odata/Releases"
}
key = getAuthKey(my_endpoint,"HMC","admin","1q2w3e4r!")
res = getUiPathAPI(api_url["Releases"],key)
res
# Out:
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'@odata.context': 'https://koreascoring.iptime.org/odata/$metadata#Releases',
#  '@odata.count': 17,
#  'value': [{'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:03.363Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 1,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': 'aa302b61-852a-4798-9c1c-3c4838840b7d',
#    'Name': 'K_BM_001_생산실적_지역별차종별_생산실적_집계_및_보고_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_001_생산실적_지역별차종별_생산실적_집계_및_보고',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7439.27621',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': '[{"name":"In_APIKey","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_Domain","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_SessionId","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_URLToken","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_UserId","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_ProcessName","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false}]',
#     'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:06.473Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 2,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '25f65657-0a9c-41f5-8b4f-bbabf858af71',
#    'Name': 'K_BM_002_DKD통관은행제출서류작성_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_002_DKD통관은행제출서류작성',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7444.20324',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:09.787Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 3,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '3c863c91-bd7d-4008-ab57-b55bc051a883',
#    'Name': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7326.29062',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:13.49Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 4,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '4e745674-957f-4017-9ba9-a93ce1454bac',
#    'Name': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7325.29010',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:16.35Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 5,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '708c5e9a-5311-49d1-a2da-24ce028c11ec',
#    'Name': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7339.24556',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:19.693Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 6,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '5937dcf3-d8c2-4867-b9d4-a23235a13ef8',
#    'Name': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7317.29579',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:23.1Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 7,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': 'd4603e13-7b9f-4f56-b44a-18451c0f179b',
#    'Name': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7348.30234',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:27.507Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 8,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': 'e0e431c3-c474-4572-bb47-6b74707db482',
#    'Name': 'K_BM_007_기아상공회의소원산지증명서신청_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_007_기아상공회의소원산지증명서신청',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7345.22804',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:32.443Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 9,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': 'ac2264a0-851b-4c8a-a6b7-ccf451669c05',
#    'Name': 'K_BM_008_해상운송비_선사확인요청_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_008_해상운송비_선사확인요청',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7325.29512',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:37.32Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 10,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '4fb86404-c12f-461d-bce1-4a7ca1cd35d1',
#    'Name': 'K_BM_009_해상운송비_전표처리_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_009_해상운송비_전표처리',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7311.20084',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:41.68Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 11,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '01ccadf3-27d2-4afc-8776-1fdf83250fb3',
#    'Name': 'K_BM_010_SAP_네고일_이후_반제처리_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_010_SAP_네고일_이후_반제처리',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7326.33798',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:45.023Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 12,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '140954ec-6c39-46ed-8b64-404169f5d4f4',
#    'Name': 'K_BM_011_DKD통관은행제출서류작성_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_011_DKD통관은행제출서류작성',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7332.28496',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:48.037Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 13,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '7464a7fb-fa7a-43a6-8966-276417e903d4',
#    'Name': 'K_BM_012_일일생산계획및야적장재고현황_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_012_일일생산계획및야적장재고현황',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7346.31827',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-14T02:09:51.083Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 14,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': 'cc236f5e-cb37-44de-90bf-17556e1bf08e',
#    'Name': 'K_CE_001_테크핫라인기술자문응대지원_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_CE_001_테크핫라인기술자문응대지원',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7326.37525',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': None, 'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-16T02:15:08.617Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 15,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '2f52b837-422a-4859-97f9-3003da8989ab',
#    'Name': 'KS_에러테스트_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'KS_에러테스트',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.7564.20211',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': '[{"name":"Str_img_Path","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"x","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Y","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Height","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"width","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Str_Ouptput_Path","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false}]',
#     'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-18T06:13:45.543Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 16,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '8e8daf03-d38d-48b7-8a38-cdfce28c4334',
#    'Name': 'K_BM_030_Monthly_Mune_Planner_업무_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_030_Monthly_Mune_Planner_업무',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.2',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False},
#   {'Arguments': {'Input': '[{"name":"Date_","type":"System.DateTime, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"email_address","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true}]',
#     'Output': None},
#    'AutoUpdate': False,
#    'CreationTime': '2020-09-18T06:13:51.31Z',
#    'Description': '',
#    'EnvironmentId': 1,
#    'EnvironmentName': 'RKBM001',
#    'FeedId': 'fa7d858f-6fae-43b2-8f2a-98f9b8fc2f5d',
#    'Id': 17,
#    'InputArguments': None,
#    'IsLatestVersion': False,
#    'IsProcessDeleted': False,
#    'JobPriority': 'Normal',
#    'Key': '3f7a69c5-6187-4d6b-b784-b31b00ccef55',
#    'Name': 'K_BM_031_Menu_Planner_E-Mail_전달_업무_RKBM001',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'ProcessKey': 'K_BM_031_Menu_Planner_E-Mail_전달_업무',
#    'ProcessSettings': None,
#    'ProcessType': 'Process',
#    'ProcessVersion': '1.0.2',
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False}]}

# %%
res = getUiPathAPI(api_url["Processes"],key)
res
# Out:
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'@odata.context': 'https://koreascoring.iptime.org/odata/$metadata#Processes',
#  '@odata.count': 17,
#  'value': [{'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_001_생산실적_지역별차종별_생산실적_집계_및_보고',
#    'Id': 'K_BM_001_생산실적_지역별차종별_생산실적_집계_및_보고',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_001_생산실적_지역별차종별_생산실적_집계_및_보고:1.0.7439.27621',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:40:48.7266667Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7439.27621'},
#   {'Arguments': {'Input': '[{"name":"In_APIKey","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_Domain","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_SessionId","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_URLToken","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_UserId","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"In_ProcessName","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false}]',
#     'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_002_DKD통관은행제출서류작성',
#    'Id': 'K_BM_002_DKD통관은행제출서류작성',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_002_DKD통관은행제출서류작성:1.0.7444.20324',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:40:55.86Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7444.20324'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고',
#    'Id': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고:1.0.7326.29062',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:01.8766667Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7326.29062'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출',
#    'Id': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출:1.0.7325.29010',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:08.3Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7325.29010'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고',
#    'Id': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고:1.0.7339.24556',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:14.55Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7339.24556'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고',
#    'Id': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고:1.0.7317.29579',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:22.97Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7317.29579'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관',
#    'Id': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관:1.0.7348.30234',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:29.6133333Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7348.30234'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_007_기아상공회의소원산지증명서신청',
#    'Id': 'K_BM_007_기아상공회의소원산지증명서신청',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_007_기아상공회의소원산지증명서신청:1.0.7345.22804',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:36.41Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7345.22804'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_008_해상운송비_선사확인요청',
#    'Id': 'K_BM_008_해상운송비_선사확인요청',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_008_해상운송비_선사확인요청:1.0.7325.29512',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:42.3166667Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7325.29512'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_009_해상운송비_전표처리',
#    'Id': 'K_BM_009_해상운송비_전표처리',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_009_해상운송비_전표처리:1.0.7311.20084',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:47.99Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7311.20084'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_010_SAP_네고일_이후_반제처리',
#    'Id': 'K_BM_010_SAP_네고일_이후_반제처리',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_010_SAP_네고일_이후_반제처리:1.0.7326.33798',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:53.8633333Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7326.33798'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_011_DKD통관은행제출서류작성',
#    'Id': 'K_BM_011_DKD통관은행제출서류작성',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_011_DKD통관은행제출서류작성:1.0.7332.28496',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:41:59.6766667Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7332.28496'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_012_일일생산계획및야적장재고현황',
#    'Id': 'K_BM_012_일일생산계획및야적장재고현황',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_012_일일생산계획및야적장재고현황:1.0.7346.31827',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:42:07.8933333Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7346.31827'},
#   {'Arguments': {'Input': '[{"name":"Str_img_Path","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false},{"name":"x","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Y","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Height","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"width","type":"System.Int32, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"Str_Ouptput_Path","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":false}]',
#     'Output': None},
#    'Authors': 'Master',
#    'Description': '빈 프로세스',
#    'Id': 'K_BM_030_Monthly_Mune_Planner_업무',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_030_Monthly_Mune_Planner_업무:1.0.2',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-18T06:13:22.09Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.2'},
#   {'Arguments': {'Input': '[{"name":"Date_","type":"System.DateTime, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true},{"name":"email_address","type":"System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089","required":false,"hasDefault":true}]',
#     'Output': None},
#    'Authors': 'Master',
#    'Description': '빈 프로세스',
#    'Id': 'K_BM_031_Menu_Planner_E-Mail_전달_업무',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_BM_031_Menu_Planner_E-Mail_전달_업무:1.0.2',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-18T06:13:32.2633333Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.2'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_CE_001_테크핫라인기술자문응대지원',
#    'Id': 'K_CE_001_테크핫라인기술자문응대지원',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'K_CE_001_테크핫라인기술자문응대지원:1.0.7326.37525',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-14T01:42:14.0666667Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7326.37525'},
#   {'Arguments': {'Input': None, 'Output': None},
#    'Authors': 'KoreaScoring',
#    'Description': 'K_BM_006_CKD수출선적_서류의_ERP_內_전산_작성_보관',
#    'Id': 'KS_에러테스트',
#    'IsActive': False,
#    'IsLatestVersion': False,
#    'Key': 'KS_에러테스트:1.0.7564.20211',
#    'OldVersion': None,
#    'ProjectType': 'Process',
#    'Published': '2020-09-16T02:14:32.74Z',
#    'ReleaseNotes': None,
#    'RequiresUserInteraction': True,
#    'SupportsMultipleEntryPoints': False,
#    'Title': None,
#    'Version': '1.0.7564.20211'}]}

# %%
res = getUiPathAPI(api_url["Robots"],key)
res
# Out:
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'@odata.context': 'https://koreascoring.iptime.org/odata/$metadata#Robots',
#  '@odata.count': 2,
#  'value': [{'CredentialStoreId': None,
#    'CredentialType': None,
#    'Description': None,
#    'Enabled': True,
#    'ExecutionSettings': None,
#    'ExternalName': None,
#    'HostingType': 'Standard',
#    'Id': 4,
#    'IsExternalLicensed': False,
#    'LicenseKey': None,
#    'LimitConcurrentExecution': False,
#    'MachineId': 4,
#    'MachineName': 'LAPTOP-ORG1DFQO',
#    'Name': 'LTBot',
#    'Password': None,
#    'ProvisionType': 'Manual',
#    'RobotEnvironments': 'RKBM001',
#    'Type': 'NonProduction',
#    'UserId': 11,
#    'Username': 'laptop-org1dfqo\\user',
#    'Version': None},
#   {'CredentialStoreId': None,
#    'CredentialType': None,
#    'Description': None,
#    'Enabled': True,
#    'ExecutionSettings': None,
#    'ExternalName': None,
#    'HostingType': 'Standard',
#    'Id': 5,
#    'IsExternalLicensed': False,
#    'LicenseKey': None,
#    'LimitConcurrentExecution': False,
#    'MachineId': 1,
#    'MachineName': 'DESKTOP-TO8MSMC',
#    'Name': 'DTBOT',
#    'Password': None,
#    'ProvisionType': 'Manual',
#    'RobotEnvironments': '',
#    'Type': 'NonProduction',
#    'UserId': 14,
#    'Username': 'desktop-to8msmc\\koreascoring',
#    'Version': None}]}

# %%
res = getUiPathAPI(api_url["Jobs"],key)
res
# Out:
# C:\Users\koreascoring\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' /> \n   위치: UiPath.UiNodeClass.FindFirst(UiFindScope scope, String nodeID)\r\n   위치: UiPath.Core.UiElement.FindFirst(FindScope scope, Selector selector, IPlaceholderResolver placeholderResolver)\n\t--- End of inner exception stack trace ---\n   위치: UiPath.Core.Activities.TaskAsyncCodeActivity`1.EndExecute(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.System.Activities.IAsyncCodeActivity.FinishExecution(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.CompleteAsyncCodeActivityData.CompleteAsyncCodeActivityWorkItem.Execute(ActivityExecutor executor, BookmarkManager bookmarkManager)",
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': '1c2388be-b859-4a82-8f77-44fb5cd1d88e',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': '{}',
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'KS_에러테스트_RKBM001',
#    'ReleaseVersionId': 15,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-11-11T00:43:50.563Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '0bc8691a-d36b-4053-99c9-e0cf0b243487',
#    'CreationTime': '2020-12-07T04:31:23.843Z',
#    'EndTime': '2020-12-07T04:31:27.16Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 209,
#    'Info': '실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA)\r\n\r\nRemoteException wrapping System.Exception: 실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA) \n',
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': 'df1e2b35-96bd-443c-8638-38a0cb97c65e',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출_RKBM001',
#    'ReleaseVersionId': 4,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-12-07T04:31:25.953Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '462bbb0b-36a3-4252-9a44-37499e37711f',
#    'CreationTime': '2020-12-07T04:43:45.13Z',
#    'EndTime': '2020-12-07T04:43:45.27Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 210,
#    'Info': '실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA)\r\n\r\nRemoteException wrapping System.Exception: 실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA) \n',
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': '31a59cd1-f4c8-41f3-aa05-d8f3d21e2923',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출_RKBM001',
#    'ReleaseVersionId': 4,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-12-07T04:43:45.237Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': 'f2e65876-c165-43b3-bc61-0b14bc27a208',
#    'CreationTime': '2020-12-07T04:44:10.707Z',
#    'EndTime': '2020-12-07T04:44:10.863Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 211,
#    'Info': '실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA)\r\n\r\nRemoteException wrapping System.Exception: 실행 프로그램을 시작할 수 없습니다. 요청한 리소스가 사용 중입니다. (예외가 발생한 HRESULT: 0x800700AA) \n',
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': 'e2c44b88-0166-4446-a6e2-1c83dce85114',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고_RKBM001',
#    'ReleaseVersionId': 5,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-12-07T04:44:10.82Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': 'eec654d3-4ad8-4c74-a2f1-e373822d55ab',
#    'CreationTime': '2020-12-07T05:16:03.153Z',
#    'EndTime': '2020-12-07T05:18:48.093Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'LAPTOP-ORG1DFQO',
#    'Id': 212,
#    'Info': 'Robot Licensing Failed. There are no available licenses on the server. (#1914).',
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': 'bdff94d0-1322-4558-91d3-f248fc4bf7ab',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_004_일일경영현황_기아현대_일일경영현황_집계_및_보고_RKBM001',
#    'ReleaseVersionId': None,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': None,
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-12-07T05:18:48.093Z',
#    'StartingScheduleId': None,
#    'State': 'Stopped',
#    'StopStrategy': 'Kill',
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': 'c7eb105c-8a58-465c-b5ed-51d88123a681',
#    'CreationTime': '2020-12-07T05:18:58.72Z',
#    'EndTime': '2020-12-07T05:22:26.7Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'LAPTOP-ORG1DFQO',
#    'Id': 213,
#    'Info': '작업이 완료되었습니다.',
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': '908f5d68-715d-4a82-aefe-fba428d4c1c8',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': '{}',
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_003_관세절감실적집계_및_가공에따른_절감효과산출_RKBM001',
#    'ReleaseVersionId': 4,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-12-07T05:18:59.173Z',
#    'StartingScheduleId': None,
#    'State': 'Successful',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '2db55671-9bfb-40af-ad82-e03983236b28',
#    'CreationTime': '2020-11-11T00:33:37.87Z',
#    'EndTime': '2020-11-11T00:33:43.637Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 204,
#    'Info': "이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />\r\n\r\nRemoteException wrapping UiPath.Core.SelectorNotFoundException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />  ---> RemoteException wrapping System.Runtime.InteropServices.COMException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' /> \n   위치: UiPath.UiNodeClass.FindFirst(UiFindScope scope, String nodeID)\r\n   위치: UiPath.Core.UiElement.FindFirst(FindScope scope, Selector selector, IPlaceholderResolver placeholderResolver)\n\t--- End of inner exception stack trace ---\n   위치: UiPath.Core.Activities.TaskAsyncCodeActivity`1.EndExecute(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.System.Activities.IAsyncCodeActivity.FinishExecution(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.CompleteAsyncCodeActivityData.CompleteAsyncCodeActivityWorkItem.Execute(ActivityExecutor executor, BookmarkManager bookmarkManager)",
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': '9d730b0b-a040-416c-8854-6c22fe8e95e3',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': '{}',
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'KS_에러테스트_RKBM001',
#    'ReleaseVersionId': 15,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-11-11T00:33:37.963Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': 'dbd9d074-f716-4997-ae66-65511a11a7c3',
#    'CreationTime': '2020-11-11T00:36:02.917Z',
#    'EndTime': '2020-11-11T00:36:08.62Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 205,
#    'Info': "이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />\r\n\r\nRemoteException wrapping UiPath.Core.SelectorNotFoundException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />  ---> RemoteException wrapping System.Runtime.InteropServices.COMException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' /> \n   위치: UiPath.UiNodeClass.FindFirst(UiFindScope scope, String nodeID)\r\n   위치: UiPath.Core.UiElement.FindFirst(FindScope scope, Selector selector, IPlaceholderResolver placeholderResolver)\n\t--- End of inner exception stack trace ---\n   위치: UiPath.Core.Activities.TaskAsyncCodeActivity`1.EndExecute(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.System.Activities.IAsyncCodeActivity.FinishExecution(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.CompleteAsyncCodeActivityData.CompleteAsyncCodeActivityWorkItem.Execute(ActivityExecutor executor, BookmarkManager bookmarkManager)",
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': 'e633b1e4-8284-4be2-b9fa-7f7724c3f23a',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': '{}',
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'KS_에러테스트_RKBM001',
#    'ReleaseVersionId': 15,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-11-11T00:36:02.98Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '07da0619-4382-408a-bd5b-240a67920227',
#    'CreationTime': '2020-11-11T00:38:40.263Z',
#    'EndTime': '2020-11-11T00:38:46.07Z',
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': 'DESKTOP-TO8MSMC',
#    'Id': 206,
#    'Info': "이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />\r\n\r\nRemoteException wrapping UiPath.Core.SelectorNotFoundException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' />  ---> RemoteException wrapping System.Runtime.InteropServices.COMException: 이 Selector에 해당하는 UI 엘리먼트를 찾을 수 없습니다. <html app='chrome.exe' title='NAVER' /><webctrl id='query' tag='INPUT' /> \n   위치: UiPath.UiNodeClass.FindFirst(UiFindScope scope, String nodeID)\r\n   위치: UiPath.Core.UiElement.FindFirst(FindScope scope, Selector selector, IPlaceholderResolver placeholderResolver)\n\t--- End of inner exception stack trace ---\n   위치: UiPath.Core.Activities.TaskAsyncCodeActivity`1.EndExecute(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.System.Activities.IAsyncCodeActivity.FinishExecution(AsyncCodeActivityContext context, IAsyncResult result)\r\n   위치: System.Activities.AsyncCodeActivity.CompleteAsyncCodeActivityData.CompleteAsyncCodeActivityWorkItem.Execute(ActivityExecutor executor, BookmarkManager bookmarkManager)",
#    'InputArguments': None,
#    'JobPriority': 'Normal',
#    'Key': 'fbbb8880-d1db-4d94-b919-cbc410c95fd7',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': '{}',
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'KS_에러테스트_RKBM001',
#    'ReleaseVersionId': 15,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': 'NonProduction',
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': '2020-11-11T00:38:40.357Z',
#    'StartingScheduleId': None,
#    'State': 'Faulted',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '7992aba4-b442-4de9-8d2e-9e5f73e05405',
#    'CreationTime': '2021-01-25T00:24:49.78Z',
#    'EndTime': None,
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': None,
#    'Id': 279,
#    'Info': None,
#    'InputArguments': '{"In_APIKey":"81fe3b992aa5020a02a80c126443faea","In_Domain":"https://api-bot.ks-cognigy.com","In_SessionId":"session-1d583006-47c3-46c8-8ae6-7125cb263631","In_URLToken":"bdec6cf4990080a1b0f10a86a40344f05cd924813a1e81f96f08db83b664f8b8","In_UserId":"5c2dc074-8a98-44c1-8c95-2cf9e53e489f","In_ProcessName":"K_BM_005_해외공장_생산진척_현황_집계_및_보고_RKBM001","In_Version":"hard","email_address":""}',
#    'JobPriority': 'Normal',
#    'Key': 'd345f989-e42a-4f49-ad18-ce1840661237',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_005_해외공장_생산진척_현황_집계_및_보고_RKBM001',
#    'ReleaseVersionId': None,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': None,
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': None,
#    'StartingScheduleId': None,
#    'State': 'Pending',
#    'StopStrategy': None,
#    'Type': 'Unattended'},
#   {'BatchExecutionKey': '979be9f4-843f-49b8-a1d8-afe8ca2431bc',
#    'CreationTime': '2021-01-25T05:01:13.227Z',
#    'EndTime': None,
#    'EntryPointPath': None,
#    'HasMediaRecorded': False,
#    'HostMachineName': None,
#    'Id': 280,
#    'Info': None,
#    'InputArguments': '{"In_APIKey":"81fe3b992aa5020a02a80c126443faea","In_Domain":"https://api-bot.ks-cognigy.com","In_SessionId":"session-db6c0b27-d0f0-4ac3-bec5-1914893b29be","In_URLToken":"bdec6cf4990080a1b0f10a86a40344f05cd924813a1e81f96f08db83b664f8b8","In_UserId":"5c2dc074-8a98-44c1-8c95-2cf9e53e489f","In_ProcessName":"K_BM_002_국내해외공장_수주예상실적_집계_및_보고_RKBM001","In_Version":"hard","email_address":""}',
#    'JobPriority': 'Normal',
#    'Key': 'de6caa89-f332-4639-941d-4f4f4c9bc12b',
#    'OrganizationUnitFullyQualifiedName': 'Default',
#    'OrganizationUnitId': 2,
#    'OutputArguments': None,
#    'PersistenceId': None,
#    'Reference': '',
#    'ReleaseName': 'K_BM_002_국내해외공장_수주예상실적_집계_및_보고_RKBM001',
#    'ReleaseVersionId': None,
#    'RequiresUserInteraction': True,
#    'ResumeVersion': None,
#    'RuntimeType': None,
#    'Source': 'Manual',
#    'SourceType': 'Manual',
#    'StartTime': None,
#    'StartingScheduleId': None,
#    'State': 'Pending',
#    'StopStrategy': None,
#    'Type': 'Unattended'}]}

# %%
## Job 실행
my_endpoint = "https://platform.uipath.com/jwpark/jwpark:443"

key = getAuthKey(my_endpoint,"jwpark","admin","input your password")
# print(reqResult)

data = {
    "startInfo": {
        "ReleaseKey": "06427f13-1bb4-4a7f-b64c-5300567c912f",
        "Strategy": "Specific",
        "RobotIds": [166814],
        "NoOfRobots": 0,
        "JobsCount": 0,
        "Source": "Manual",
        "InputArguments": None
    }
}
res = postUiPathAPI(my_endpoint+"/odata/Jobs/UiPath.Server.Configuration.OData.StartJobs",key,data)
print(res)

# %%
## robot,job,process 정보 읽어오기
api_url = "https://platform.uipath.com/jwpark/jwpark:443"
data = {
    "tenancyName": "jwpark",
    "usernameOrEmailAddress": "admin",
    "password": "input your password"

}
sess = requests.Session()
req = requests.post(api_url+"/api/Account/Authenticate",data)
resJson = req.json()
reqResult = resJson["result"]
print(reqResult)
head = {
    "Content-Type" : "application/json",
    "Authorization" : "Bearer " + reqResult
}

print("********** Robots Info")
req = requests.get(api_url+"/odata/Robots",headers=head)#?$filter=Name eq 'ROBOT007'",headers=head)
if(req.status_code == 200):
    pretty(req.json())
else:
    print(req)

print("********** Jobs Info")
req = requests.get(api_url+"/odata/Jobs",headers=head)#?$filter=Name eq 'ROBOT007'",headers=head)
if(req.status_code == 200):
    pretty(req.json())
else:
    print(req)

print("********** Processes Info")
req = requests.get(api_url+"/odata/Processes",headers=head)#?$filter=Name eq 'ROBOT007'",headers=head)
if(req.status_code == 200):
    pretty(req.json())
else:
    print(req)
    
print("********** Releases Info")
req = requests.get(api_url+"/odata/Releases",headers=head)#?$filter=Name eq 'ROBOT007'",headers=head)
if(req.status_code == 200):
    pretty(req.json())
else:
    print(req)
